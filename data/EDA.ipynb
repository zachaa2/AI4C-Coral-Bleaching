# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the metadata files
ABB = pd.read_csv('outputs\images\Altieri Biscayne Bay\metadata.csv')
ARU = pd.read_csv('outputs\images\Curacao Coral Reef Assessment 2023 ARU\metadata.csv')
CUR = pd.read_csv('outputs\images\Curacao Coral Reef Assessment 2023 CUR\metadata.csv')
WAPACI = pd.read_csv('outputs\images\WAPA Coral Inventory 2.0\metadata.csv')
WAPACT = pd.read_csv('outputs\images\WAPA CoralNet Training\metadata.csv')
WAPAI = pd.read_csv('outputs\images\WAPA Interns\metadata.csv')

# Combine the metadata files
metadata = pd.concat([ABB, ARU, CUR, WAPACI, WAPACT, WAPAI])
metadata.to_csv('outputs/images/combined_metadata.csv', index=False)

# %%
# EDA on collect date
date = metadata['date']
dates = dict()
for d in reversed(date):
    if d in dates:
        dates[d] += 1
    else:
        dates[d] = 1
plt.figure(figsize=(14, 8))
plt.bar(dates.keys(), dates.values())
plt.xticks(rotation=45)
plt.tight_layout()
plt.title('Number of images collected per day')#3255 images in total
plt.show()

# %%
# EDA on location
location = metadata['location']
locations = dict()
for l in location:
    if l in locations:
        locations[l] += 1
    else:
        locations[l] = 1
colors = ['blue', 'orange', 'green']
plt.pie(locations.values(), labels=None, colors=colors, autopct='%1.1f%%')
plt.legend(locations.keys(), title="Locations", loc="upper left", bbox_to_anchor=(0.9, 1))
plt.title('Distribution of images per location')

plt.show()

# %%
#EDA on labels
label = metadata['label']
labels = dict()
for l in label:
    if l in labels:
        labels[l] += 1
    else:
        labels[l] = 1
color = ["pink", "purple", "grey"]
plt.pie(labels.values(), labels=None, colors=color, autopct='%1.1f%%')
plt.legend(labels.keys(), title="status", loc="upper left", bbox_to_anchor=(0.9, 1))
plt.title('Distribution of coral per status')
plt.show()

# %%
BiscayneBay = metadata[metadata['location'] == 'Biscayne Bay']
BiscayneBay_label = BiscayneBay['label']
BiscayneBay_labels = dict()
for l in BiscayneBay_label:
    if l in BiscayneBay_labels:
        BiscayneBay_labels[l] += 1
    else:
        BiscayneBay_labels[l] = 1
color = ["pink", "purple", "grey"]
plt.pie(BiscayneBay_labels.values(), labels=None, colors=color, autopct='%1.1f%%')
plt.legend(BiscayneBay_labels.keys(), title="status", loc="upper left", bbox_to_anchor=(0.9, 1))
plt.title('Distribution of coral per status in Biscayne Bay')#28 images
plt.show()

# %%
Curacao = metadata[metadata['location'] == 'Curacao']
Curacao_label = Curacao['label']
Curacao_labels = dict()
for l in Curacao_label:
    if l in Curacao_labels:
        Curacao_labels[l] += 1
    else:
        Curacao_labels[l] = 1
color = ["pink", "purple", "grey"]
plt.pie(Curacao_labels.values(), labels=None, colors=color, autopct='%1.1f%%')
plt.legend(Curacao_labels.keys(), title="status", loc="upper left", bbox_to_anchor=(0.9, 1))
plt.title('Distribution of coral per status in Curacao')# 1809 images
plt.show()

# %%
PNHP = metadata[metadata['location'] == 'Pacific National Historical Park, Guam']
PNHP_label = PNHP['label']
PNHP_labels = dict()
for l in PNHP_label:
    if l in PNHP_labels:
        PNHP_labels[l] += 1
    else:
        PNHP_labels[l] = 1
color = ["pink", "purple", "grey"]
plt.pie(PNHP_labels.values(), labels=None, colors=color, autopct='%1.1f%%')
plt.legend(PNHP_labels.keys(), title="status", loc="upper left", bbox_to_anchor=(0.9, 1))
plt.title('Distribution of coral per status in Pacific National Historical Park')# 1418 images
# Out:
# Text(0.5, 1.0, 'Distribution of coral per status in Pacific National Historical Park')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
t = Curacao = metadata[metadata['location'] == 'Pacific National Historical Park, Guam']
data = pd.DataFrame({
    'Temperature': t['SST@90th_HS'],
    'Coral Health': t['label']
})

# Set up the figure size
plt.figure(figsize=(10, 6))

# Create a box plot to show temperature distribution for each coral health label
sns.boxplot(x='Coral Health', y='Temperature', data=data, palette='Set2')

# Add labels and title
plt.xlabel('Coral Health Status')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Distribution for Each Coral Health Status')

# Display the plot
plt.show()
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_21708\3658404070.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Coral Health', y='Temperature', data=data, palette='Set2')

# %%
plt.figure(figsize=(10, 6))

# Create a violin plot to show temperature distribution for each coral health label
sns.violinplot(x='Coral Health', y='Temperature', data=data, palette='Set2')

# Add labels and title
plt.xlabel('Coral Health Status')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Distribution for Each Coral Health Status in Pacific National Historical Park')

# Display the plot
plt.show()
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_21708\2350378756.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Coral Health', y='Temperature', data=data, palette='Set2')
